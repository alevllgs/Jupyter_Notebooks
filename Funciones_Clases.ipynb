# %% [markdown]
# # Funciones

# %%
def modificar():
   print("informacion")
   print("...")
   print("...")
   print("...")
   return
print(modificar())
# Out:
# informacion
# ...
# ...
# ...
# None

# %% [markdown]
# Puedo asignar variables directo

# %%
def f(a=7, b=3):
  return a-b
print(f())
# Out:
# 4

# %% [markdown]
# # Clases

# %% [markdown]
# **Clase o instancia** permite que la creación y el manejo de los objetos se sencillo, es una plantilla que nos indica cuales deben ser las caracteristicas y acciones que debe hacer cada objeto.
#
# **Objeto** puede ser un ojeto real como una cuenta, un apellido, un número de serie o abstracto como una ecuación, una fracción o un número complejo. Cada objeto tiene un conjunto de características que lo definen asi como un conjunto de acciones que determinan su comportamiento con respecto a otros objetos.
#
# Atributo es el valor que almacena internamente el objeto

# %%
class Nombre_clase:
